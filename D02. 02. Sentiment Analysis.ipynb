# %%
import nltk

####
# text to work with
bltext = """It was a dark and stormy night; the rain fell in torrents, except at
occasional intervals, when it was checked by a violent gust of wind
which swept up the streets (for it is in London that our scene lies),
rattling along the house-tops, and fiercely agitating the scanty flame
of the lamps that struggled against the darkness. Through one of the
obscurest quarters of London, and among haunts little loved by the
gentlemen of the police, a man, evidently of the lowest orders, was
wending his solitary way. He stopped twice or thrice at different shops
and houses of a description correspondent with the appearance of the
quartier in which they were situated, and tended inquiry for some
article or another which did not seem easily to be met with. All the
answers he received were couched in the negative; and as he turned from
each door he muttered to himself, in no very elegant phraseology, his
disappointment and discontent. At length, at one house, the landlord, a
sturdy butcher, after rendering the same reply the inquirer had hitherto
received, added, "But if this vill do as vell, Dummie, it is quite at
your sarvice!" Pausing reflectively for a moment, Dummie responded that
he thought the thing proffered might do as well; and thrusting it into
his ample pocket, he strode away with as rapid a motion as the wind and
the rain would allow. He soon came to a nest of low and dingy buildings,
at the entrance to which, in half-effaced characters, was written
"Thames Court." Halting at the most conspicuous of these buildings, an
inn or alehouse, through the half-closed windows of which blazed out in
ruddy comfort the beams of the hospitable hearth, he knocked hastily at
the door. He was admitted by a lady of a certain age, and endowed with a
comely rotundity of face and person."""

# split up into sentences
sent_detector = nltk.data.load('tokenizers/punkt/english.pickle')
blsentences = sent_detector.tokenize(bltext.strip())

print ("Split into sentences.")
print (blsentences[0])

###
# split up each sentence into words, taking punctuation into account
blsent_words = [nltk.word_tokenize(sent) for sent in blsentences]

print ("Split into words.")
print (blsent_words[0])

###
# add part-of-speech tags: a list of sentences, each of which is a list of word/tag pairs
blsent_tagged = [nltk.pos_tag(sent) for sent in blsent_words]

print ("Added part-of-speech tags.")
print (blsent_tagged[0])

###
# add named-entity tags
# blsent_ne: list of sentences, each of which is a list of word/tag/NEtag triples
# (we do not go on using these below)
blsent_ne = [nltk.chunk.tree2conlltags(nltk.ne_chunk(s)) for s in blsent_tagged]

print ("Added named-entity tags.")
print (blsent_ne[0])

###
# chunking
# IOB format
# code from the NLTK book
class UnigramChunker(nltk.ChunkParserI):
    def __init__(self, train_sents): 
        train_data = [[(t,c) for w,t,c in nltk.chunk.tree2conlltags(sent)]
                      for sent in train_sents]
        self.tagger = nltk.UnigramTagger(train_data)
             
    def parse(self, sentence): 
        return nltk.chunk.conlltags2tree(self.parse_iob(sentence))
    
    def parse_iob(self, sentence):
        pos_tags = [pos for (word,pos) in sentence]
        tagged_pos_tags = self.tagger.tag(pos_tags)
        chunktags = [chunktag for (pos, chunktag) in tagged_pos_tags]
        conlltags = [(word, pos, chunktag) for ((word,pos),chunktag)
                     in zip(sentence, chunktags)]
        return conlltags

from nltk.corpus import conll2000
train_sents = conll2000.chunked_sents('train.txt', chunk_types=['NP'])
chunker = UnigramChunker(train_sents)

# blsent_chunked: triples (word, postag, chunktag)
print ("Added chunk tags to word/tag pairs (version 1)")
blsent_chunked = [ chunker.parse_iob(s) for s in blsent_tagged ]
print (blsent_chunked[0])

# or, second option for chunking: via regular expressions
grammar = r"""
  NP: {<DT|PP\$>?<JJ.*>*<NN.*>+}   # chunk determiner/possessive, adjectives and noun sequences
"""
chunker2 = nltk.RegexpParser(grammar)

# blsent_chunked2: triples (word, postag, chunktag)
blsent_chunked2= [nltk.chunk.tree2conlltags(chunker2.parse(s)) for s in blsent_tagged ]

print ("Added chunk tags to word/tag pairs (version 2)")
print (blsent_chunked2[0])

###
#lemmatization
lobj = nltk.stem.wordnet.WordNetLemmatizer()

# a list of sentences, each of which is a list of  word/tag/chunktag/lemma tuples
blsent_lemmatized = [ ]

for sent in blsent_chunked:
    onesentence = [ ]
    
    for word, postag, chunktag in sent:
        if postag.startswith("V"): shorttag = "v"
        elif postag.startswith("N"): shorttag = "n"
        elif postag.startswith("J"): shorttag = "a"
        else: shorttag = "n"
        onesentence.append( (word, postag, chunktag, lobj.lemmatize(word.lower(), shorttag)))
        
    blsent_lemmatized.append(onesentence)

print ("Added lemmas.")
print (blsent_lemmatized[0])
    
###
# positive and negative sentiment tags
def read_sentiment_lexicon(filename):
    f = open(filename)
    words = [ ]
    for line in f:
        if not(line.startswith(";")) and not(line.strip() == ""):
            words.append(line.strip())
    f.close()
    return set(words)

poswords = read_sentiment_lexicon("data/nlp/positive-words.txt")
negwords = read_sentiment_lexicon("data/nlp/negative-words.txt")

blsent_sentiment = [ ]
for sent in blsent_lemmatized:
    onesentence = [ ]
    
    for word, postag, chunktag, lemma in sent:
        if lemma in poswords:
            onesentence.append( (word, postag, chunktag, lemma, "POS"))
        elif lemma in negwords:
            onesentence.append( (word, postag, chunktag, lemma, "NEG"))
        else:
            onesentence.append( (word, postag, chunktag, lemma, "O"))

    blsent_sentiment.append(onesentence)

print ("Added pos/neg sentiment tags")
print (blsent_sentiment[0])

#how many positive and negative sentiment words in the text?
num_pos = len([wtuple for sent in blsent_sentiment for wtuple in sent if wtuple[-1] == "POS"])
num_neg = len([wtuple for sent in blsent_sentiment for wtuple in sent if wtuple[-1] == "NEG"])
print ("Count of positive sentiment words:", num_pos)
print ("Count of negative sentiment words:", num_neg)
# Out:
# Split into sentences.
# It was a dark and stormy night; the rain fell in torrents, except at
# occasional intervals, when it was checked by a violent gust of wind
# which swept up the streets (for it is in London that our scene lies),
# rattling along the house-tops, and fiercely agitating the scanty flame
# of the lamps that struggled against the darkness.
# Split into words.
# ['It', 'was', 'a', 'dark', 'and', 'stormy', 'night', ';', 'the', 'rain', 'fell', 'in', 'torrents', ',', 'except', 'at', 'occasional', 'intervals', ',', 'when', 'it', 'was', 'checked', 'by', 'a', 'violent', 'gust', 'of', 'wind', 'which', 'swept', 'up', 'the', 'streets', '(', 'for', 'it', 'is', 'in', 'London', 'that', 'our', 'scene', 'lies', ')', ',', 'rattling', 'along', 'the', 'house-tops', ',', 'and', 'fiercely', 'agitating', 'the', 'scanty', 'flame', 'of', 'the', 'lamps', 'that', 'struggled', 'against', 'the', 'darkness', '.']
# Added part-of-speech tags.
# [('It', 'PRP'), ('was', 'VBD'), ('a', 'DT'), ('dark', 'NN'), ('and', 'CC'), ('stormy', 'NN'), ('night', 'NN'), (';', ':'), ('the', 'DT'), ('rain', 'NN'), ('fell', 'VBD'), ('in', 'IN'), ('torrents', 'NNS'), (',', ','), ('except', 'IN'), ('at', 'IN'), ('occasional', 'JJ'), ('intervals', 'NNS'), (',', ','), ('when', 'WRB'), ('it', 'PRP'), ('was', 'VBD'), ('checked', 'VBN'), ('by', 'IN'), ('a', 'DT'), ('violent', 'JJ'), ('gust', 'NN'), ('of', 'IN'), ('wind', 'NN'), ('which', 'WDT'), ('swept', 'VBD'), ('up', 'RP'), ('the', 'DT'), ('streets', 'NNS'), ('(', '('), ('for', 'IN'), ('it', 'PRP'), ('is', 'VBZ'), ('in', 'IN'), ('London', 'NNP'), ('that', 'IN'), ('our', 'PRP$'), ('scene', 'NN'), ('lies', 'VBZ'), (')', ')'), (',', ','), ('rattling', 'VBG'), ('along', 'IN'), ('the', 'DT'), ('house-tops', 'NNS'), (',', ','), ('and', 'CC'), ('fiercely', 'RB'), ('agitating', 'VBG'), ('the', 'DT'), ('scanty', 'NN'), ('flame', 'NN'), ('of', 'IN'), ('the', 'DT'), ('lamps', 'NNS'), ('that', 'WDT'), ('struggled', 'VBD'), ('against', 'IN'), ('the', 'DT'), ('darkness', 'NN'), ('.', '.')]
# Added named-entity tags.
# [('It', 'PRP', 'O'), ('was', 'VBD', 'O'), ('a', 'DT', 'O'), ('dark', 'NN', 'O'), ('and', 'CC', 'O'), ('stormy', 'NN', 'O'), ('night', 'NN', 'O'), (';', ':', 'O'), ('the', 'DT', 'O'), ('rain', 'NN', 'O'), ('fell', 'VBD', 'O'), ('in', 'IN', 'O'), ('torrents', 'NNS', 'O'), (',', ',', 'O'), ('except', 'IN', 'O'), ('at', 'IN', 'O'), ('occasional', 'JJ', 'O'), ('intervals', 'NNS', 'O'), (',', ',', 'O'), ('when', 'WRB', 'O'), ('it', 'PRP', 'O'), ('was', 'VBD', 'O'), ('checked', 'VBN', 'O'), ('by', 'IN', 'O'), ('a', 'DT', 'O'), ('violent', 'JJ', 'O'), ('gust', 'NN', 'O'), ('of', 'IN', 'O'), ('wind', 'NN', 'O'), ('which', 'WDT', 'O'), ('swept', 'VBD', 'O'), ('up', 'RP', 'O'), ('the', 'DT', 'O'), ('streets', 'NNS', 'O'), ('(', '(', 'O'), ('for', 'IN', 'O'), ('it', 'PRP', 'O'), ('is', 'VBZ', 'O'), ('in', 'IN', 'O'), ('London', 'NNP', 'B-GPE'), ('that', 'IN', 'O'), ('our', 'PRP$', 'O'), ('scene', 'NN', 'O'), ('lies', 'VBZ', 'O'), (')', ')', 'O'), (',', ',', 'O'), ('rattling', 'VBG', 'O'), ('along', 'IN', 'O'), ('the', 'DT', 'O'), ('house-tops', 'NNS', 'O'), (',', ',', 'O'), ('and', 'CC', 'O'), ('fiercely', 'RB', 'O'), ('agitating', 'VBG', 'O'), ('the', 'DT', 'O'), ('scanty', 'NN', 'O'), ('flame', 'NN', 'O'), ('of', 'IN', 'O'), ('the', 'DT', 'O'), ('lamps', 'NNS', 'O'), ('that', 'WDT', 'O'), ('struggled', 'VBD', 'O'), ('against', 'IN', 'O'), ('the', 'DT', 'O'), ('darkness', 'NN', 'O'), ('.', '.', 'O')]
# Added chunk tags to word/tag pairs (version 1)
# [('It', 'PRP', 'B-NP'), ('was', 'VBD', 'O'), ('a', 'DT', 'B-NP'), ('dark', 'NN', 'I-NP'), ('and', 'CC', 'O'), ('stormy', 'NN', 'I-NP'), ('night', 'NN', 'I-NP'), (';', ':', 'O'), ('the', 'DT', 'B-NP'), ('rain', 'NN', 'I-NP'), ('fell', 'VBD', 'O'), ('in', 'IN', 'O'), ('torrents', 'NNS', 'I-NP'), (',', ',', 'O'), ('except', 'IN', 'O'), ('at', 'IN', 'O'), ('occasional', 'JJ', 'I-NP'), ('intervals', 'NNS', 'I-NP'), (',', ',', 'O'), ('when', 'WRB', 'O'), ('it', 'PRP', 'B-NP'), ('was', 'VBD', 'O'), ('checked', 'VBN', 'O'), ('by', 'IN', 'O'), ('a', 'DT', 'B-NP'), ('violent', 'JJ', 'I-NP'), ('gust', 'NN', 'I-NP'), ('of', 'IN', 'O'), ('wind', 'NN', 'I-NP'), ('which', 'WDT', 'B-NP'), ('swept', 'VBD', 'O'), ('up', 'RP', 'O'), ('the', 'DT', 'B-NP'), ('streets', 'NNS', 'I-NP'), ('(', '(', 'O'), ('for', 'IN', 'O'), ('it', 'PRP', 'B-NP'), ('is', 'VBZ', 'O'), ('in', 'IN', 'O'), ('London', 'NNP', 'I-NP'), ('that', 'IN', 'O'), ('our', 'PRP$', 'B-NP'), ('scene', 'NN', 'I-NP'), ('lies', 'VBZ', 'O'), (')', ')', 'O'), (',', ',', 'O'), ('rattling', 'VBG', 'O'), ('along', 'IN', 'O'), ('the', 'DT', 'B-NP'), ('house-tops', 'NNS', 'I-NP'), (',', ',', 'O'), ('and', 'CC', 'O'), ('fiercely', 'RB', 'O'), ('agitating', 'VBG', 'O'), ('the', 'DT', 'B-NP'), ('scanty', 'NN', 'I-NP'), ('flame', 'NN', 'I-NP'), ('of', 'IN', 'O'), ('the', 'DT', 'B-NP'), ('lamps', 'NNS', 'I-NP'), ('that', 'WDT', 'B-NP'), ('struggled', 'VBD', 'O'), ('against', 'IN', 'O'), ('the', 'DT', 'B-NP'), ('darkness', 'NN', 'I-NP'), ('.', '.', 'O')]
# Added chunk tags to word/tag pairs (version 2)
# [('It', 'PRP', 'O'), ('was', 'VBD', 'O'), ('a', 'DT', 'B-NP'), ('dark', 'NN', 'I-NP'), ('and', 'CC', 'O'), ('stormy', 'NN', 'B-NP'), ('night', 'NN', 'I-NP'), (';', ':', 'O'), ('the', 'DT', 'B-NP'), ('rain', 'NN', 'I-NP'), ('fell', 'VBD', 'O'), ('in', 'IN', 'O'), ('torrents', 'NNS', 'B-NP'), (',', ',', 'O'), ('except', 'IN', 'O'), ('at', 'IN', 'O'), ('occasional', 'JJ', 'B-NP'), ('intervals', 'NNS', 'I-NP'), (',', ',', 'O'), ('when', 'WRB', 'O'), ('it', 'PRP', 'O'), ('was', 'VBD', 'O'), ('checked', 'VBN', 'O'), ('by', 'IN', 'O'), ('a', 'DT', 'B-NP'), ('violent', 'JJ', 'I-NP'), ('gust', 'NN', 'I-NP'), ('of', 'IN', 'O'), ('wind', 'NN', 'B-NP'), ('which', 'WDT', 'O'), ('swept', 'VBD', 'O'), ('up', 'RP', 'O'), ('the', 'DT', 'B-NP'), ('streets', 'NNS', 'I-NP'), ('(', '(', 'O'), ('for', 'IN', 'O'), ('it', 'PRP', 'O'), ('is', 'VBZ', 'O'), ('in', 'IN', 'O'), ('London', 'NNP', 'B-NP'), ('that', 'IN', 'O'), ('our', 'PRP$', 'O'), ('scene', 'NN', 'B-NP'), ('lies', 'VBZ', 'O'), (')', ')', 'O'), (',', ',', 'O'), ('rattling', 'VBG', 'O'), ('along', 'IN', 'O'), ('the', 'DT', 'B-NP'), ('house-tops', 'NNS', 'I-NP'), (',', ',', 'O'), ('and', 'CC', 'O'), ('fiercely', 'RB', 'O'), ('agitating', 'VBG', 'O'), ('the', 'DT', 'B-NP'), ('scanty', 'NN', 'I-NP'), ('flame', 'NN', 'I-NP'), ('of', 'IN', 'O'), ('the', 'DT', 'B-NP'), ('lamps', 'NNS', 'I-NP'), ('that', 'WDT', 'O'), ('struggled', 'VBD', 'O'), ('against', 'IN', 'O'), ('the', 'DT', 'B-NP'), ('darkness', 'NN', 'I-NP'), ('.', '.', 'O')]
# Added lemmas.
# [('It', 'PRP', 'B-NP', 'it'), ('was', 'VBD', 'O', 'be'), ('a', 'DT', 'B-NP', 'a'), ('dark', 'NN', 'I-NP', 'dark'), ('and', 'CC', 'O', 'and'), ('stormy', 'NN', 'I-NP', 'stormy'), ('night', 'NN', 'I-NP', 'night'), (';', ':', 'O', ';'), ('the', 'DT', 'B-NP', 'the'), ('rain', 'NN', 'I-NP', 'rain'), ('fell', 'VBD', 'O', 'fell'), ('in', 'IN', 'O', 'in'), ('torrents', 'NNS', 'I-NP', 'torrent'), (',', ',', 'O', ','), ('except', 'IN', 'O', 'except'), ('at', 'IN', 'O', 'at'), ('occasional', 'JJ', 'I-NP', 'occasional'), ('intervals', 'NNS', 'I-NP', 'interval'), (',', ',', 'O', ','), ('when', 'WRB', 'O', 'when'), ('it', 'PRP', 'B-NP', 'it'), ('was', 'VBD', 'O', 'be'), ('checked', 'VBN', 'O', 'check'), ('by', 'IN', 'O', 'by'), ('a', 'DT', 'B-NP', 'a'), ('violent', 'JJ', 'I-NP', 'violent'), ('gust', 'NN', 'I-NP', 'gust'), ('of', 'IN', 'O', 'of'), ('wind', 'NN', 'I-NP', 'wind'), ('which', 'WDT', 'B-NP', 'which'), ('swept', 'VBD', 'O', 'sweep'), ('up', 'RP', 'O', 'up'), ('the', 'DT', 'B-NP', 'the'), ('streets', 'NNS', 'I-NP', 'street'), ('(', '(', 'O', '('), ('for', 'IN', 'O', 'for'), ('it', 'PRP', 'B-NP', 'it'), ('is', 'VBZ', 'O', 'be'), ('in', 'IN', 'O', 'in'), ('London', 'NNP', 'I-NP', 'london'), ('that', 'IN', 'O', 'that'), ('our', 'PRP$', 'B-NP', 'our'), ('scene', 'NN', 'I-NP', 'scene'), ('lies', 'VBZ', 'O', 'lie'), (')', ')', 'O', ')'), (',', ',', 'O', ','), ('rattling', 'VBG', 'O', 'rattle'), ('along', 'IN', 'O', 'along'), ('the', 'DT', 'B-NP', 'the'), ('house-tops', 'NNS', 'I-NP', 'house-tops'), (',', ',', 'O', ','), ('and', 'CC', 'O', 'and'), ('fiercely', 'RB', 'O', 'fiercely'), ('agitating', 'VBG', 'O', 'agitate'), ('the', 'DT', 'B-NP', 'the'), ('scanty', 'NN', 'I-NP', 'scanty'), ('flame', 'NN', 'I-NP', 'flame'), ('of', 'IN', 'O', 'of'), ('the', 'DT', 'B-NP', 'the'), ('lamps', 'NNS', 'I-NP', 'lamp'), ('that', 'WDT', 'B-NP', 'that'), ('struggled', 'VBD', 'O', 'struggle'), ('against', 'IN', 'O', 'against'), ('the', 'DT', 'B-NP', 'the'), ('darkness', 'NN', 'I-NP', 'darkness'), ('.', '.', 'O', '.')]
# Added pos/neg sentiment tags
# [('It', 'PRP', 'B-NP', 'it', 'O'), ('was', 'VBD', 'O', 'be', 'O'), ('a', 'DT', 'B-NP', 'a', 'O'), ('dark', 'NN', 'I-NP', 'dark', 'NEG'), ('and', 'CC', 'O', 'and', 'O'), ('stormy', 'NN', 'I-NP', 'stormy', 'NEG'), ('night', 'NN', 'I-NP', 'night', 'O'), (';', ':', 'O', ';', 'O'), ('the', 'DT', 'B-NP', 'the', 'O'), ('rain', 'NN', 'I-NP', 'rain', 'O'), ('fell', 'VBD', 'O', 'fell', 'NEG'), ('in', 'IN', 'O', 'in', 'O'), ('torrents', 'NNS', 'I-NP', 'torrent', 'NEG'), (',', ',', 'O', ',', 'O'), ('except', 'IN', 'O', 'except', 'O'), ('at', 'IN', 'O', 'at', 'O'), ('occasional', 'JJ', 'I-NP', 'occasional', 'O'), ('intervals', 'NNS', 'I-NP', 'interval', 'O'), (',', ',', 'O', ',', 'O'), ('when', 'WRB', 'O', 'when', 'O'), ('it', 'PRP', 'B-NP', 'it', 'O'), ('was', 'VBD', 'O', 'be', 'O'), ('checked', 'VBN', 'O', 'check', 'O'), ('by', 'IN', 'O', 'by', 'O'), ('a', 'DT', 'B-NP', 'a', 'O'), ('violent', 'JJ', 'I-NP', 'violent', 'NEG'), ('gust', 'NN', 'I-NP', 'gust', 'O'), ('of', 'IN', 'O', 'of', 'O'), ('wind', 'NN', 'I-NP', 'wind', 'O'), ('which', 'WDT', 'B-NP', 'which', 'O'), ('swept', 'VBD', 'O', 'sweep', 'O'), ('up', 'RP', 'O', 'up', 'O'), ('the', 'DT', 'B-NP', 'the', 'O'), ('streets', 'NNS', 'I-NP', 'street', 'O'), ('(', '(', 'O', '(', 'O'), ('for', 'IN', 'O', 'for', 'O'), ('it', 'PRP', 'B-NP', 'it', 'O'), ('is', 'VBZ', 'O', 'be', 'O'), ('in', 'IN', 'O', 'in', 'O'), ('London', 'NNP', 'I-NP', 'london', 'O'), ('that', 'IN', 'O', 'that', 'O'), ('our', 'PRP$', 'B-NP', 'our', 'O'), ('scene', 'NN', 'I-NP', 'scene', 'O'), ('lies', 'VBZ', 'O', 'lie', 'NEG'), (')', ')', 'O', ')', 'O'), (',', ',', 'O', ',', 'O'), ('rattling', 'VBG', 'O', 'rattle', 'NEG'), ('along', 'IN', 'O', 'along', 'O'), ('the', 'DT', 'B-NP', 'the', 'O'), ('house-tops', 'NNS', 'I-NP', 'house-tops', 'O'), (',', ',', 'O', ',', 'O'), ('and', 'CC', 'O', 'and', 'O'), ('fiercely', 'RB', 'O', 'fiercely', 'O'), ('agitating', 'VBG', 'O', 'agitate', 'O'), ('the', 'DT', 'B-NP', 'the', 'O'), ('scanty', 'NN', 'I-NP', 'scanty', 'O'), ('flame', 'NN', 'I-NP', 'flame', 'O'), ('of', 'IN', 'O', 'of', 'O'), ('the', 'DT', 'B-NP', 'the', 'O'), ('lamps', 'NNS', 'I-NP', 'lamp', 'O'), ('that', 'WDT', 'B-NP', 'that', 'O'), ('struggled', 'VBD', 'O', 'struggle', 'NEG'), ('against', 'IN', 'O', 'against', 'O'), ('the', 'DT', 'B-NP', 'the', 'O'), ('darkness', 'NN', 'I-NP', 'darkness', 'NEG'), ('.', '.', 'O', '.', 'O')]
# Count of positive sentiment words: 9
# Count of negative sentiment words: 18
