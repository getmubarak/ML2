# %%
from keras.layers import Dense, Dropout, LSTM, Embedding
from keras.preprocessing.sequence import pad_sequences
from keras.models import Sequential
import pandas as pd
import numpy as np

input_file = 'data/timeSeries/input.csv'

def load_data(test_split = 0.2):
    print ('Loading data...')
    df = pd.read_csv(input_file)
    df['sequence'] = df['sequence'].apply(lambda x: [int(e) for e in x.split()])
    df = df.reindex(np.random.permutation(df.index))

    train_size = int(len(df) * (1 - test_split))

    X_train = df['sequence'].values[:train_size]
    y_train = np.array(df['target'].values[:train_size])
    X_test = np.array(df['sequence'].values[train_size:])
    y_test = np.array(df['target'].values[train_size:])

    return pad_sequences(X_train), y_train, pad_sequences(X_test), y_test


def create_model(input_length):
    print ('Creating model...')
    model = Sequential()
    model.add(Embedding(input_dim = 188, output_dim = 50, input_length = input_length))
    model.add(LSTM(output_dim=256, activation='sigmoid', inner_activation='hard_sigmoid', return_sequences=True))
    model.add(Dropout(0.5))
    model.add(LSTM(output_dim=256, activation='sigmoid', inner_activation='hard_sigmoid'))
    model.add(Dropout(0.5))
    model.add(Dense(1, activation='sigmoid'))

    print ('Compiling...')
    model.compile(loss='binary_crossentropy',
                  optimizer='rmsprop',
                  metrics=['accuracy'])
    return model


X_train, y_train, X_test, y_test = load_data()

model = create_model(len(X_train[0]))

print ('Fitting model...')
hist = model.fit(X_train, y_train, batch_size=64, nb_epoch=100, validation_split = 0.1, verbose = 1)
#hist = model.fit(X_train, y_train, batch_size=10, nb_epoch=10, validation_split = 0.1, verbose = 1)

score, acc = model.evaluate(X_test, y_test, batch_size=1)
print('Test score:', score)
print('Test accuracy:', acc)
# Out:
# /opt/ds/lib/python3.4/site-packages/ipykernel/__main__.py:29: UserWarning: Update your `LSTM` call to the Keras 2 API: `LSTM(return_sequences=True, activation="sigmoid", units=256, recurrent_activation="hard_sigmoid")`
# /opt/ds/lib/python3.4/site-packages/ipykernel/__main__.py:31: UserWarning: Update your `LSTM` call to the Keras 2 API: `LSTM(recurrent_activation="hard_sigmoid", activation="sigmoid", units=256)`
# Loading data...
# Creating model...
# Compiling...
# Fitting model...
# Train on 6 samples, validate on 1 samples
# Epoch 1/100
# 6/6 [==============================] - 4s 622ms/step - loss: 0.6985 - acc: 0.6667 - val_loss: 1.2064 - val_acc: 0.0000e+00
# Epoch 2/100
# 6/6 [==============================] - 0s 8ms/step - loss: 0.6918 - acc: 0.6667 - val_loss: 1.2315 - val_acc: 0.0000e+00
# Epoch 3/100
# 6/6 [==============================] - 0s 8ms/step - loss: 0.7116 - acc: 0.6667 - val_loss: 1.0174 - val_acc: 0.0000e+00
# Epoch 4/100
# 6/6 [==============================] - 0s 9ms/step - loss: 0.6981 - acc: 0.5000 - val_loss: 1.1609 - val_acc: 0.0000e+00
# Epoch 5/100
# 6/6 [==============================] - 0s 12ms/step - loss: 0.8540 - acc: 0.6667 - val_loss: 0.9835 - val_acc: 0.0000e+00
# Epoch 6/100
# 6/6 [==============================] - 0s 42ms/step - loss: 0.6559 - acc: 0.6667 - val_loss: 0.9920 - val_acc: 0.0000e+00
# Epoch 7/100
# 6/6 [==============================] - 0s 22ms/step - loss: 0.6804 - acc: 0.5000 - val_loss: 1.2514 - val_acc: 0.0000e+00
# Epoch 8/100
# 6/6 [==============================] - 0s 19ms/step - loss: 0.5503 - acc: 0.6667 - val_loss: 1.1955 - val_acc: 0.0000e+00
# Epoch 9/100
# 6/6 [==============================] - 0s 14ms/step - loss: 0.7013 - acc: 0.6667 - val_loss: 1.1980 - val_acc: 0.0000e+00
# Epoch 10/100
# 6/6 [==============================] - 0s 13ms/step - loss: 0.8429 - acc: 0.6667 - val_loss: 1.1135 - val_acc: 0.0000e+00
# Epoch 11/100
# 6/6 [==============================] - 0s 13ms/step - loss: 0.6001 - acc: 0.6667 - val_loss: 0.9893 - val_acc: 0.0000e+00
# Epoch 12/100
# 6/6 [==============================] - 0s 10ms/step - loss: 0.7139 - acc: 0.5000 - val_loss: 1.0847 - val_acc: 0.0000e+00
# Epoch 13/100
# 6/6 [==============================] - 0s 13ms/step - loss: 0.6930 - acc: 0.6667 - val_loss: 1.1189 - val_acc: 0.0000e+00
# Epoch 14/100
# 6/6 [==============================] - 0s 24ms/step - loss: 0.6245 - acc: 0.6667 - val_loss: 1.1391 - val_acc: 0.0000e+00
# Epoch 15/100
# 6/6 [==============================] - 0s 8ms/step - loss: 0.7790 - acc: 0.6667 - val_loss: 1.1099 - val_acc: 0.0000e+00
# Epoch 16/100
# 6/6 [==============================] - 0s 15ms/step - loss: 0.6957 - acc: 0.5000 - val_loss: 1.1011 - val_acc: 0.0000e+00
# Epoch 17/100
# 6/6 [==============================] - 0s 21ms/step - loss: 0.6920 - acc: 0.5000 - val_loss: 1.1064 - val_acc: 0.0000e+00
# Epoch 18/100
# 6/6 [==============================] - 0s 16ms/step - loss: 0.6652 - acc: 0.5000 - val_loss: 1.1918 - val_acc: 0.0000e+00
# Epoch 19/100
# 6/6 [==============================] - 0s 17ms/step - loss: 0.7665 - acc: 0.6667 - val_loss: 1.1204 - val_acc: 0.0000e+00
# Epoch 20/100
# 6/6 [==============================] - 0s 11ms/step - loss: 0.7438 - acc: 0.5000 - val_loss: 1.2042 - val_acc: 0.0000e+00
# Epoch 21/100
# 6/6 [==============================] - 0s 10ms/step - loss: 0.8543 - acc: 0.5000 - val_loss: 1.1618 - val_acc: 0.0000e+00
# Epoch 22/100
# 6/6 [==============================] - 0s 9ms/step - loss: 0.6965 - acc: 0.6667 - val_loss: 1.1210 - val_acc: 0.0000e+00
# Epoch 23/100
# 6/6 [==============================] - 0s 8ms/step - loss: 0.7555 - acc: 0.5000 - val_loss: 1.0739 - val_acc: 0.0000e+00
# Epoch 24/100
# 6/6 [==============================] - 0s 8ms/step - loss: 0.6649 - acc: 0.5000 - val_loss: 1.1341 - val_acc: 0.0000e+00
# Epoch 25/100
# 6/6 [==============================] - 0s 9ms/step - loss: 0.6552 - acc: 0.6667 - val_loss: 1.1367 - val_acc: 0.0000e+00
# Epoch 26/100
# 6/6 [==============================] - 0s 8ms/step - loss: 0.5432 - acc: 0.8333 - val_loss: 1.1509 - val_acc: 0.0000e+00
# Epoch 27/100
# 6/6 [==============================] - 0s 11ms/step - loss: 0.5752 - acc: 0.5000 - val_loss: 1.1300 - val_acc: 0.0000e+00
# Epoch 28/100
# 6/6 [==============================] - 0s 8ms/step - loss: 0.7634 - acc: 0.5000 - val_loss: 1.1939 - val_acc: 0.0000e+00
# Epoch 29/100
# 6/6 [==============================] - 0s 10ms/step - loss: 0.7343 - acc: 0.5000 - val_loss: 1.2155 - val_acc: 0.0000e+00
# Epoch 30/100
# 6/6 [==============================] - 0s 23ms/step - loss: 0.7124 - acc: 0.6667 - val_loss: 1.2688 - val_acc: 0.0000e+00
# Epoch 31/100
# 6/6 [==============================] - 0s 10ms/step - loss: 0.7766 - acc: 0.6667 - val_loss: 1.3036 - val_acc: 0.0000e+00
# Epoch 32/100
# 6/6 [==============================] - 0s 10ms/step - loss: 0.5487 - acc: 0.6667 - val_loss: 1.2144 - val_acc: 0.0000e+00
# Epoch 33/100
# 6/6 [==============================] - 0s 10ms/step - loss: 0.6234 - acc: 0.6667 - val_loss: 1.1939 - val_acc: 0.0000e+00
# Epoch 34/100
# 6/6 [==============================] - 0s 12ms/step - loss: 0.7072 - acc: 0.6667 - val_loss: 1.2280 - val_acc: 0.0000e+00
# Epoch 35/100
# 6/6 [==============================] - 0s 11ms/step - loss: 0.5789 - acc: 0.6667 - val_loss: 1.1710 - val_acc: 0.0000e+00
# Epoch 36/100
# 6/6 [==============================] - 0s 12ms/step - loss: 0.5981 - acc: 0.6667 - val_loss: 1.0659 - val_acc: 0.0000e+00
# Epoch 37/100
# 6/6 [==============================] - 0s 11ms/step - loss: 0.5581 - acc: 0.6667 - val_loss: 1.1255 - val_acc: 0.0000e+00
# Epoch 38/100
# 6/6 [==============================] - 0s 11ms/step - loss: 0.6582 - acc: 0.8333 - val_loss: 1.2169 - val_acc: 0.0000e+00
# Epoch 39/100
# 6/6 [==============================] - 0s 11ms/step - loss: 0.6590 - acc: 0.5000 - val_loss: 1.2435 - val_acc: 0.0000e+00
# Epoch 40/100
# 6/6 [==============================] - 0s 10ms/step - loss: 0.5712 - acc: 0.6667 - val_loss: 1.1712 - val_acc: 0.0000e+00
# Epoch 41/100
# 6/6 [==============================] - 0s 12ms/step - loss: 0.6439 - acc: 0.6667 - val_loss: 1.1614 - val_acc: 0.0000e+00
# Epoch 42/100
# 6/6 [==============================] - 0s 11ms/step - loss: 0.6672 - acc: 0.6667 - val_loss: 1.1513 - val_acc: 0.0000e+00
# Epoch 43/100
# 6/6 [==============================] - 0s 14ms/step - loss: 0.5390 - acc: 0.8333 - val_loss: 1.1383 - val_acc: 0.0000e+00
# Epoch 44/100
# 6/6 [==============================] - 0s 11ms/step - loss: 0.5889 - acc: 0.6667 - val_loss: 1.2246 - val_acc: 0.0000e+00
# Epoch 45/100
# 6/6 [==============================] - 0s 12ms/step - loss: 0.7997 - acc: 0.5000 - val_loss: 1.3439 - val_acc: 0.0000e+00
# Epoch 46/100
# 6/6 [==============================] - 0s 15ms/step - loss: 0.6300 - acc: 0.6667 - val_loss: 1.2835 - val_acc: 0.0000e+00
# Epoch 47/100
# 6/6 [==============================] - 0s 12ms/step - loss: 0.5549 - acc: 0.6667 - val_loss: 1.1662 - val_acc: 0.0000e+00
# Epoch 48/100
# 6/6 [==============================] - 0s 11ms/step - loss: 0.5646 - acc: 0.6667 - val_loss: 1.0159 - val_acc: 0.0000e+00
# Epoch 49/100
# 6/6 [==============================] - 0s 9ms/step - loss: 0.5915 - acc: 0.6667 - val_loss: 1.1284 - val_acc: 0.0000e+00
# Epoch 50/100
# 6/6 [==============================] - 0s 11ms/step - loss: 0.5971 - acc: 0.6667 - val_loss: 1.1887 - val_acc: 0.0000e+00
# Epoch 51/100
# 6/6 [==============================] - 0s 12ms/step - loss: 0.6116 - acc: 0.8333 - val_loss: 1.3102 - val_acc: 0.0000e+00
# Epoch 52/100
# 6/6 [==============================] - 0s 13ms/step - loss: 0.5153 - acc: 0.8333 - val_loss: 1.2178 - val_acc: 0.0000e+00
# Epoch 53/100
# 6/6 [==============================] - 0s 11ms/step - loss: 0.5411 - acc: 0.6667 - val_loss: 1.1413 - val_acc: 0.0000e+00
# Epoch 54/100
# 6/6 [==============================] - 0s 15ms/step - loss: 0.6236 - acc: 0.8333 - val_loss: 1.1592 - val_acc: 0.0000e+00
# Epoch 55/100
# 6/6 [==============================] - 0s 14ms/step - loss: 0.5849 - acc: 0.6667 - val_loss: 1.0792 - val_acc: 0.0000e+00
# Epoch 56/100
# 6/6 [==============================] - 0s 21ms/step - loss: 0.4294 - acc: 1.0000 - val_loss: 1.2300 - val_acc: 0.0000e+00
# Epoch 57/100
# 6/6 [==============================] - 0s 9ms/step - loss: 0.6294 - acc: 0.6667 - val_loss: 1.2322 - val_acc: 0.0000e+00
# Epoch 58/100
# 6/6 [==============================] - 0s 62ms/step - loss: 0.6197 - acc: 0.6667 - val_loss: 1.2452 - val_acc: 0.0000e+00
# Epoch 59/100
# 6/6 [==============================] - 0s 11ms/step - loss: 0.6158 - acc: 0.5000 - val_loss: 1.2049 - val_acc: 0.0000e+00
# Epoch 60/100
# 6/6 [==============================] - 0s 10ms/step - loss: 0.4505 - acc: 0.6667 - val_loss: 1.2070 - val_acc: 0.0000e+00
# Epoch 61/100
# 6/6 [==============================] - 0s 12ms/step - loss: 0.4599 - acc: 0.8333 - val_loss: 1.2701 - val_acc: 0.0000e+00
# Epoch 62/100
# 6/6 [==============================] - 0s 10ms/step - loss: 0.5798 - acc: 0.8333 - val_loss: 1.4697 - val_acc: 0.0000e+00
# Epoch 63/100
# 6/6 [==============================] - 0s 12ms/step - loss: 0.5106 - acc: 0.6667 - val_loss: 1.2912 - val_acc: 0.0000e+00
# Epoch 64/100
# 6/6 [==============================] - 0s 12ms/step - loss: 0.5015 - acc: 0.6667 - val_loss: 1.2981 - val_acc: 0.0000e+00
# Epoch 65/100
# 6/6 [==============================] - 0s 9ms/step - loss: 0.4216 - acc: 0.8333 - val_loss: 1.3111 - val_acc: 0.0000e+00
# Epoch 66/100
# 6/6 [==============================] - 0s 12ms/step - loss: 0.6209 - acc: 0.6667 - val_loss: 1.3308 - val_acc: 0.0000e+00
# Epoch 67/100
# 6/6 [==============================] - 0s 9ms/step - loss: 0.5281 - acc: 0.6667 - val_loss: 1.3381 - val_acc: 0.0000e+00
# Epoch 68/100
# 6/6 [==============================] - 0s 9ms/step - loss: 0.7454 - acc: 0.6667 - val_loss: 1.0771 - val_acc: 0.0000e+00
# Epoch 69/100
# 6/6 [==============================] - 0s 10ms/step - loss: 0.5411 - acc: 0.8333 - val_loss: 1.2854 - val_acc: 0.0000e+00
# Epoch 70/100
# 6/6 [==============================] - 0s 8ms/step - loss: 0.6275 - acc: 0.6667 - val_loss: 1.1790 - val_acc: 0.0000e+00
# Epoch 71/100
# 6/6 [==============================] - 0s 8ms/step - loss: 0.4110 - acc: 1.0000 - val_loss: 1.4843 - val_acc: 0.0000e+00
# Epoch 72/100
# 6/6 [==============================] - 0s 9ms/step - loss: 0.5435 - acc: 0.6667 - val_loss: 1.2221 - val_acc: 0.0000e+00
# Epoch 73/100
# 6/6 [==============================] - 0s 9ms/step - loss: 0.4570 - acc: 0.8333 - val_loss: 1.3102 - val_acc: 0.0000e+00
# Epoch 74/100
# 6/6 [==============================] - 0s 9ms/step - loss: 0.3957 - acc: 0.8333 - val_loss: 1.1917 - val_acc: 0.0000e+00
# Epoch 75/100
# 6/6 [==============================] - 0s 10ms/step - loss: 0.5631 - acc: 0.6667 - val_loss: 1.2591 - val_acc: 0.0000e+00
# Epoch 76/100
# 6/6 [==============================] - 0s 11ms/step - loss: 0.3618 - acc: 0.8333 - val_loss: 1.2165 - val_acc: 0.0000e+00
# Epoch 77/100
# 6/6 [==============================] - 0s 9ms/step - loss: 0.4192 - acc: 0.8333 - val_loss: 1.4165 - val_acc: 0.0000e+00
# Epoch 78/100
# 6/6 [==============================] - 0s 10ms/step - loss: 0.2978 - acc: 1.0000 - val_loss: 1.4119 - val_acc: 0.0000e+00
# Epoch 79/100
# 6/6 [==============================] - 0s 9ms/step - loss: 0.4982 - acc: 0.6667 - val_loss: 1.2859 - val_acc: 0.0000e+00
# Epoch 80/100
# 6/6 [==============================] - 0s 8ms/step - loss: 0.5021 - acc: 0.8333 - val_loss: 1.3716 - val_acc: 0.0000e+00
# Epoch 81/100
# 6/6 [==============================] - 0s 8ms/step - loss: 0.5582 - acc: 0.8333 - val_loss: 1.3154 - val_acc: 0.0000e+00
# Epoch 82/100
# 6/6 [==============================] - 0s 9ms/step - loss: 0.3935 - acc: 0.8333 - val_loss: 1.2691 - val_acc: 0.0000e+00
# Epoch 83/100
# 6/6 [==============================] - 0s 12ms/step - loss: 0.3347 - acc: 1.0000 - val_loss: 1.3127 - val_acc: 0.0000e+00
# Epoch 84/100
# 6/6 [==============================] - 0s 10ms/step - loss: 0.3412 - acc: 1.0000 - val_loss: 1.6340 - val_acc: 0.0000e+00
# Epoch 85/100
# 6/6 [==============================] - 0s 9ms/step - loss: 0.4200 - acc: 0.8333 - val_loss: 1.3329 - val_acc: 0.0000e+00
# Epoch 86/100
# 6/6 [==============================] - 0s 10ms/step - loss: 0.3209 - acc: 0.8333 - val_loss: 1.3661 - val_acc: 0.0000e+00
# Epoch 87/100
# 6/6 [==============================] - 0s 11ms/step - loss: 0.3698 - acc: 1.0000 - val_loss: 1.7211 - val_acc: 0.0000e+00
# Epoch 88/100
# 6/6 [==============================] - 0s 10ms/step - loss: 0.2811 - acc: 1.0000 - val_loss: 1.7529 - val_acc: 0.0000e+00
# Epoch 89/100
# 6/6 [==============================] - 0s 9ms/step - loss: 0.3780 - acc: 0.8333 - val_loss: 1.7172 - val_acc: 0.0000e+00
# Epoch 90/100
# 6/6 [==============================] - 0s 10ms/step - loss: 0.3837 - acc: 0.8333 - val_loss: 1.4777 - val_acc: 0.0000e+00
# Epoch 91/100
# 6/6 [==============================] - 0s 10ms/step - loss: 0.2041 - acc: 1.0000 - val_loss: 1.7736 - val_acc: 0.0000e+00
# Epoch 92/100
# 6/6 [==============================] - 0s 9ms/step - loss: 0.3179 - acc: 1.0000 - val_loss: 1.9107 - val_acc: 0.0000e+00
# Epoch 93/100
# 6/6 [==============================] - 0s 9ms/step - loss: 0.2828 - acc: 0.8333 - val_loss: 1.4307 - val_acc: 0.0000e+00
# Epoch 94/100
# 6/6 [==============================] - 0s 9ms/step - loss: 0.2173 - acc: 1.0000 - val_loss: 1.7475 - val_acc: 0.0000e+00
# Epoch 95/100
# 6/6 [==============================] - 0s 9ms/step - loss: 0.2856 - acc: 0.8333 - val_loss: 1.7540 - val_acc: 0.0000e+00
# Epoch 96/100
# 6/6 [==============================] - 0s 9ms/step - loss: 0.1453 - acc: 1.0000 - val_loss: 1.8907 - val_acc: 0.0000e+00
# Epoch 97/100
# 6/6 [==============================] - 0s 9ms/step - loss: 0.2036 - acc: 1.0000 - val_loss: 2.0215 - val_acc: 0.0000e+00
# Epoch 98/100
# 6/6 [==============================] - 0s 9ms/step - loss: 0.2044 - acc: 1.0000 - val_loss: 1.8119 - val_acc: 0.0000e+00
# Epoch 99/100
# 6/6 [==============================] - 0s 8ms/step - loss: 0.1880 - acc: 1.0000 - val_loss: 2.0041 - val_acc: 0.0000e+00
# Epoch 100/100
# 6/6 [==============================] - 0s 9ms/step - loss: 0.1425 - acc: 1.0000 - val_loss: 2.1100 - val_acc: 0.0000e+00
# 2/2 [==============================] - 0s 8ms/step
# Test score: 0.9905144423246384
# Test accuracy: 0.5
# /opt/ds/lib/python3.4/site-packages/ipykernel/__main__.py:47: UserWarning: The `nb_epoch` argument in `fit` has been renamed `epochs`.

# %%
model.predict(X_train)
# Out:
# array([[0.07574878],
#        [0.7562237 ],
#        [0.0720194 ],
#        [0.10662436],
#        [0.67261785],
#        [0.0800442 ],
#        [0.12124313]], dtype=float32)

# %%
X_train
# Out:
# array([[4, 3, 1],
#        [1, 2, 4],
#        [2, 3, 1],
#        [3, 2, 1],
#        [2, 3, 4],
#        [2, 1, 3],
#        [1, 2, 3]], dtype=int32)
