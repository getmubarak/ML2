# %%
import numpy as np

np.random.seed(1234)

# 1. Data Preprocess and declare 
x = np.array([
    [1,0,0],
    [1,1,0],
    [1,1,1]
])

y = np.array([
    [1],
    [2],
    [3]
])

# %% [raw]
#  We are only going to have two weights, Wx (Where we are going to multiple with the input x) and Wrec (Where we are going to multiple with the previous states)

# %%
# 1.3 Starting Weights - however - 
# the best set of weights would be wx = 1 and wrec = 1
wx = [0.2]
wrec = [1.5]

# %% [raw]
# Current_State_K = Previous_State K * Wrec + Current_Input_X * Wx

# %%
# Hyper Par
number_or_epoch = 30000
number_of_training_data = 3
learning_rate_x = 0.02
learning_rate_rec = 0.0006

# np array
states = np.zeros((3,4))
grad_over_time = np.zeros((3,4))

# 2. Start the Training
for iter in range(number_or_epoch):

    # 2.3 Feed Forward of the network
    layer_1 = x[:,0] * wx + states[:,0] * wrec
    states[:,1] = layer_1

    layer_2 = x[:,1] * wx + states[:,1] * wrec
    states[:,2] = layer_2

    layer_3 = x[:,2] * wx + states[:,2] * wrec
    states[:,3] = layer_3
 
    cost = np.square(states[:,3] - y).sum() / number_of_training_data

    grad_out = (states[:,3] - np.squeeze(y)) * 2 / number_of_training_data
    grad_over_time[:,3] = grad_out
    grad_over_time[:,2] = grad_over_time[:,3] * wrec
    grad_over_time[:,1] = grad_over_time[:,2] * wrec

    # NOTE: Do Not really need grad_over_time[:,0]
    grad_over_time[:,0] = grad_over_time[:,1] * wrec

    # 
    grad_wx = np.sum(grad_over_time[:,3] * x[:,2] + 
                     grad_over_time[:,2] * x[:,1]  + 
                     grad_over_time[:,1] * x[:,0])

    grad_rec = np.sum(grad_over_time[:,3] * states[:,2] + 
                      grad_over_time[:,2] * states[:,1]  + 
                      grad_over_time[:,1] * states[:,0])
    
    wx = wx - learning_rate_x * grad_wx
    wrec = wrec - learning_rate_rec * grad_rec

    if iter%1000 == 0:
        print('Current Epoch: ',iter, '  current predition :' ,layer_3)
    

# 3. Final Output and rounded resutls
layer_1 = x[:,0] * wx + states[:,0] * wrec
states[:,1] = layer_1

layer_2 = x[:,1] * wx + states[:,1] * wrec
states[:,2] = layer_2

layer_3 = x[:,2] * wx + states[:,2] * wrec
states[:,3] = layer_3

print('Ground Truth: ',layer_3)
print('Rounded Truth: ',np.round(layer_3))
print("Final weight X : ",wx)
print("Final weight Rec : ",wrec)
# Out:
# ('Current Epoch: ', 0, '  current predition :', array([ 0.45,  0.75,  0.95]))
# ('Current Epoch: ', 1000, '  current predition :', array([ 1.24937979,  2.14122399,  2.77784872]))
# ('Current Epoch: ', 2000, '  current predition :', array([ 1.20042229,  2.11969506,  2.82366601]))
# ('Current Epoch: ', 3000, '  current predition :', array([ 1.15290926,  2.09586925,  2.86711256]))
# ('Current Epoch: ', 4000, '  current predition :', array([ 1.11042022,  2.07215036,  2.90510067]))
# ('Current Epoch: ', 5000, '  current predition :', array([ 1.07569428,  2.05108986,  2.93553869]))
# ('Current Epoch: ', 6000, '  current predition :', array([ 1.04965627,  2.03431564,  2.95800286]))
# ('Current Epoch: ', 7000, '  current predition :', array([ 1.03149962,  2.02212185,  2.97348661]))
# ('Current Epoch: ', 8000, '  current predition :', array([ 1.01951566,  2.01385019,  2.98362553]))
# ('Current Epoch: ', 9000, '  current predition :', array([ 1.01190331,  2.00850373,  2.99003268]))
# ('Current Epoch: ', 10000, '  current predition :', array([ 1.00718835,  2.00515631,  2.99398827]))
# ('Current Epoch: ', 11000, '  current predition :', array([ 1.00431431,  2.00310238,  2.99639461]))
# ('Current Epoch: ', 12000, '  current predition :', array([ 1.00257964,  2.00185776,  2.99784523]))
# ('Current Epoch: ', 13000, '  current predition :', array([ 1.00153894,  2.00110928,  2.99871488]))
# ('Current Epoch: ', 14000, '  current predition :', array([ 1.00091684,  2.00066121,  2.9992345 ]))
# ('Current Epoch: ', 15000, '  current predition :', array([ 1.00054577,  2.00039373,  2.99954436]))
# ('Current Epoch: ', 16000, '  current predition :', array([ 1.00032472,  2.00023431,  2.99972892]))
# ('Current Epoch: ', 17000, '  current predition :', array([ 1.00019315,  2.00013938,  2.99983876]))
# ('Current Epoch: ', 18000, '  current predition :', array([ 1.00011487,  2.0000829 ,  2.99990411]))
# ('Current Epoch: ', 19000, '  current predition :', array([ 1.00006831,  2.0000493 ,  2.99994298]))
# ('Current Epoch: ', 20000, '  current predition :', array([ 1.00004062,  2.00002931,  2.9999661 ]))
# ('Current Epoch: ', 21000, '  current predition :', array([ 1.00002415,  2.00001743,  2.99997984]))
# ('Current Epoch: ', 22000, '  current predition :', array([ 1.00001436,  2.00001036,  2.99998801]))
# ('Current Epoch: ', 23000, '  current predition :', array([ 1.00000854,  2.00000616,  2.99999287]))
# ('Current Epoch: ', 24000, '  current predition :', array([ 1.00000508,  2.00000366,  2.99999576]))
# ('Current Epoch: ', 25000, '  current predition :', array([ 1.00000302,  2.00000218,  2.99999748]))
# ('Current Epoch: ', 26000, '  current predition :', array([ 1.00000179,  2.0000013 ,  2.9999985 ]))
# ('Current Epoch: ', 27000, '  current predition :', array([ 1.00000107,  2.00000077,  2.99999911]))
# ('Current Epoch: ', 28000, '  current predition :', array([ 1.00000063,  2.00000046,  2.99999947]))
# ('Current Epoch: ', 29000, '  current predition :', array([ 1.00000038,  2.00000027,  2.99999969]))
# ('Ground Truth: ', array([ 1.00000022,  2.00000016,  2.99999981]))
# ('Rounded Truth: ', array([ 1.,  2.,  3.]))
# ('Final weight X : ', array([ 0.99999965]))
# ('Final weight Rec : ', array([ 1.00000029]))
